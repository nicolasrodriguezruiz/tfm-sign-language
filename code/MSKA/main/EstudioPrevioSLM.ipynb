# %% [markdown]
# # Estudiando las frases

# %%
import pandas as pd

# %%
df = pd.read_pickle('/home/user/work/Preprocessing/MSKA/Dataset/data/Phoenix-2014T.train.pkl')
rows = []

for k, v in df.items():
    rows.append({
        "id": k,
        "name": v["name"],
        "gloss": v["gloss"],
        "text": v["text"],
        "num_frames": v["num_frames"],
        "keypoint_shape": tuple(v["keypoint"].shape)
    })

df = pd.DataFrame(rows)
df.head()
# Out:
#                                       id  \
# 0   11August_2010_Wednesday_tagesschau-1
# 1    25October_2010_Monday_tagesschau-15
# 2   11August_2010_Wednesday_tagesschau-7
# 3   11August_2010_Wednesday_tagesschau-9
# 4  11August_2010_Wednesday_tagesschau-13
#
#                                     name  \
# 0   11August_2010_Wednesday_tagesschau-1
# 1    25October_2010_Monday_tagesschau-15
# 2   11August_2010_Wednesday_tagesschau-7
# 3   11August_2010_Wednesday_tagesschau-9
# 4  11August_2010_Wednesday_tagesschau-13
#
#                                                gloss  \
# 0      JETZT WETTER MORGEN DONNERSTAG ZWOELF FEBRUAR
# 1  ITALIEN IX TIEF DRUCK KOMMEN HEUTE NACHT BERG ...
# 2                       WOLKE LOCH SPEZIELL NORDWEST
# 3        FLUSS HEUTE NACHT SECHS FLUSS SIEBZEHN GRAD
# 4                          TEMPERATUR BLEIBEN GLEICH
#
#                                                 text  num_frames  \
# 0  und nun die wettervorhersage für morgen donner...          86
# 1  das tief über italien sorgt dafür dass es an d...         138
# 2  größere wolkenlücken finden sich vor allem im ...          71
# 3  im emsland heute nacht nur neun am oberrhein b...         105
# 4              am temperaturniveau ändert sich wenig          48
#
#   keypoint_shape
# 0   (86, 136, 3)
# 1  (138, 136, 3)
# 2   (71, 136, 3)
# 3  (105, 136, 3)
# 4   (48, 136, 3)

# %%
from transformers import AutoTokenizer

# Cargar el tokenizador
tokenizer_path = "Qwen/Qwen2.5-1.5B"
tokenizer = AutoTokenizer.from_pretrained(tokenizer_path, trust_remote_code=True)

# Función para contar tokens
def count_qwen_tokens(text):
    if not isinstance(text, str):
        return 0
    # Tokenizamos sin truncar para ver la longitud real completa
    return len(tokenizer(text, truncation=False)['input_ids'])

print("Calculando longitudes de tokens...")

# Aplicar la función a las columnas de Texto y Glosas
df['text_tokens'] = df['text'].apply(count_qwen_tokens)


# Mostrar las estadísticas con percentiles
print("\n" + "="*50)
print("📊 ESTADÍSTICAS DE TOKENS DE TEXTO (Alemán)")
print("="*50)
print(df['text_tokens'].describe(percentiles=[0.5, 0.75, 0.90, 0.95, 0.99]))

# Ver la relación Fotogramas vs Tokens
df['ratio_frames_text'] = df['num_frames'] / df['text_tokens']
print("\n" + "="*50)
print("RATIO: Fotogramas de video por cada Token de texto")
print("="*50)
print(df['ratio_frames_text'].describe())
# Out:
# Calculando longitudes de tokens...
#
# ==================================================
# 📊 ESTADÍSTICAS DE TOKENS DE TEXTO (Alemán)
# ==================================================
# count    7096.000000
# mean       23.590614
# std         9.722534
# min         3.000000
# 50%        22.000000
# 75%        29.000000
# 90%        37.000000
# 95%        41.000000
# 99%        51.000000
# max        78.000000
# Name: text_tokens, dtype: float64
#
# ==================================================
# RATIO: Fotogramas de video por cada Token de texto
# ==================================================
# count    7096.000000
# mean        5.028114
# std         1.179292
# min         0.551724
# 25%         4.318182
# 50%         4.951800
# 75%         5.619048
# max        18.800000
# Name: ratio_frames_text, dtype: float64

# %%
df
# Out:
#                                          id  \
# 0      11August_2010_Wednesday_tagesschau-1
# 1       25October_2010_Monday_tagesschau-15
# 2      11August_2010_Wednesday_tagesschau-7
# 3      11August_2010_Wednesday_tagesschau-9
# 4     11August_2010_Wednesday_tagesschau-13
# ...                                     ...
# 7091  27January_2013_Sunday_tagesschau-8837
# 7092  27January_2013_Sunday_tagesschau-8831
# 7093  27January_2013_Sunday_tagesschau-8841
# 7094        22July_2010_Thursday_heute-8812
# 7095  27January_2013_Sunday_tagesschau-8832
#
#                                        name  \
# 0      11August_2010_Wednesday_tagesschau-1
# 1       25October_2010_Monday_tagesschau-15
# 2      11August_2010_Wednesday_tagesschau-7
# 3      11August_2010_Wednesday_tagesschau-9
# 4     11August_2010_Wednesday_tagesschau-13
# ...                                     ...
# 7091  27January_2013_Sunday_tagesschau-8837
# 7092  27January_2013_Sunday_tagesschau-8831
# 7093  27January_2013_Sunday_tagesschau-8841
# 7094        22July_2010_Thursday_heute-8812
# 7095  27January_2013_Sunday_tagesschau-8832
#
#                                                   gloss  \
# 0         JETZT WETTER MORGEN DONNERSTAG ZWOELF FEBRUAR
# 1     ITALIEN IX TIEF DRUCK KOMMEN HEUTE NACHT BERG ...
# 2                          WOLKE LOCH SPEZIELL NORDWEST
# 3           FLUSS HEUTE NACHT SECHS FLUSS SIEBZEHN GRAD
# 4                             TEMPERATUR BLEIBEN GLEICH
# ...                                                 ...
# 7091    MORGEN TATSAECHLICH FROST negalp-KEIN EINS ACHT
# 7092  HEUTE NACHT REGION SCHNEE REGEN VORSICHT GLATT...
# 7093  DONNERSTAG FREUNDLICH SONNE DANN SPAETER KOMME...
# 7094  MAXIMAL TEMPERATUR UNGEFAEHR FUENF ZWANZIG GRA...
# 7095  BESONDERS NORD NORDWEST WOLKE VERSCHWINDEN TEI...
#
#                                                    text  num_frames  \
# 0     und nun die wettervorhersage für morgen donner...          86
# 1     das tief über italien sorgt dafür dass es an d...         138
# 2     größere wolkenlücken finden sich vor allem im ...          71
# 3     im emsland heute nacht nur neun am oberrhein b...         105
# 4                 am temperaturniveau ändert sich wenig          48
# ...                                                 ...         ...
# 7091  morgen seit längerem wieder frostfrei ein grad...         104
# 7092  heute nacht gibt es im osten und süden noch sc...         115
# 7093  der donnerstag beginnt oft freundlich später z...          77
# 7094  die höchsttemperatur die wird so etwa bei fünf...         179
# 7095  vor allem im norden und westen klart es gebiet...         117
#
#      keypoint_shape  text_tokens  ratio_frames_text
# 0      (86, 136, 3)           19           4.526316
# 1     (138, 136, 3)           26           5.307692
# 2      (71, 136, 3)           16           4.437500
# 3     (105, 136, 3)           21           5.000000
# 4      (48, 136, 3)           10           4.800000
# ...             ...          ...                ...
# 7091  (104, 136, 3)           23           4.521739
# 7092  (115, 136, 3)           32           3.593750
# 7093   (77, 136, 3)           18           4.277778
# 7094  (179, 136, 3)           32           5.593750
# 7095  (117, 136, 3)           23           5.086957
#
# [7096 rows x 8 columns]
